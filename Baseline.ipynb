# %%
# =========================
#version00
# =========================

import os
import random
import glob
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from tqdm import tqdm

import matplotlib.pyplot as plt
from korean_lunar_calendar import KoreanLunarCalendar


plt.rcParams['font.family'] = 'AppleGothic'  # macOS

#Fixed Random Seed  & Setting Hyperparameter
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(42)

LOOKBACK, PREDICT, BATCH_SIZE, EPOCHS = 28, 7, 32, 50
DEVICE = torch.device("cpu")
MONTH_SCALE = 12

MIN_SEQUENCE_COUNT = 10

# 키: '영업장명_메뉴명', 값: 'YYYY-MM-DD' (ISO 문자열 또는 datetime)
DISCONTINUED = {
    '담하_꼬막_비빔밥': '2024-04-01',
    '담하_들깨_양지탕': '2024-04-01',
    # ...
}

def get_lunar_to_solar(years, lunar_month, lunar_day, span=1):
    calendar = KoreanLunarCalendar()
    dates = []
    for year in years:
        for offset in range(-span, span+1):
            try:
                calendar.setLunar(year, lunar_month, lunar_day + offset, False)
                dates.append(calendar.SolarIsoFormat())
            except:
                pass  # 예외 처리: 음력 마지막날 초과
    return dates
# 예시: 2023 ~ 2025
years = [2023, 2024, 2025]
lunar_solar_dates = []
lunar_solar_dates += get_lunar_to_solar(years, 1, 1, span=1)   # 설날 ±1
lunar_solar_dates += get_lunar_to_solar(years, 8, 15, span=1)  # 추석 ±1

solar_md_holidays = [
    (1, 1),   # 신정
    (3, 1),   # 삼일절
    (5, 5),   # 어린이날
    (6, 6),   # 현충일
    (8, 15),  # 광복절
    (10, 3),  # 개천절
    (10, 9),  # 한글날
    (12, 25), # 크리스마스
]

def generate_combined_holiday_list(df, solar_md_list, lunar_solar_list):
    df = df.copy()
    df['영업일자'] = pd.to_datetime(df['영업일자'])

    # 양력 기반 holiday 판별
    df['is_solar_holiday'] = df['영업일자'].apply(
        lambda x: (x.month, x.day) in solar_md_list
    )

    # 음력 변환된 holiday 포함
    lunar_set = set(pd.to_datetime(lunar_solar_list))
    df['is_lunar_holiday'] = df['영업일자'].isin(lunar_set)

    # 최종 통합
    df['is_holiday'] = (df['is_solar_holiday'] | df['is_lunar_holiday']).astype(int)
    df = df.drop(columns=['is_solar_holiday', 'is_lunar_holiday'])
    return df

#Define Model
class MultiEmbeddingLSTM(nn.Module):
    def __init__(
        self,
        input_dim,                  # 수치 feature 수
        hidden_dim=64,
        num_layers=2,
        output_dim=7,
        num_weekdays=7,
        weekday_embed_dim=3,
        num_seasons=4,
        season_embed_dim=2,
        dropout=0.3
    ):
        super().__init__()

        # 임베딩
        self.weekday_embedding = nn.Embedding(num_weekdays, weekday_embed_dim)
        self.season_embedding = nn.Embedding(num_seasons, season_embed_dim)

        # LayerNorm for embedding
        self.weekday_norm = nn.LayerNorm(weekday_embed_dim)
        self.season_norm = nn.LayerNorm(season_embed_dim)

        # Dropout after embedding
        self.embedding_dropout = nn.Dropout(dropout)

        total_input_dim = input_dim + weekday_embed_dim + season_embed_dim

        # LSTM
        self.lstm = nn.LSTM(total_input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)

        # LSTM output dropout
        self.post_lstm_dropout = nn.Dropout(dropout)

        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, weekday_ids, season_ids):
        """
        x: (B, T, input_dim)
        weekday_ids: (B, T)
        season_ids: (B, T)
        """
        weekday_embed = self.weekday_embedding(weekday_ids)      # (B, T, D2)
        season_embed = self.season_embedding(season_ids)         # (B, T, D3)

        # 정규화
        weekday_embed = self.weekday_norm(weekday_embed)
        season_embed = self.season_norm(season_embed)

        x_concat = torch.cat([x, weekday_embed, season_embed], dim=-1)  # (B, T, total_dim)
        x_concat = self.embedding_dropout(x_concat)

        out, _ = self.lstm(x_concat)
        out = self.post_lstm_dropout(out)

        return self.fc(out[:, -1, :])
    
def clip_iqr(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    upper = q3 + 1.5 * iqr
    return np.clip(series, None, upper)

def compute_iqr_lower_bounds(train_df):
    lower_bounds = {}
    for menu, group in train_df.groupby('영업장명_메뉴명'):
        q1 = group['매출수량'].quantile(0.25)
        q3 = group['매출수량'].quantile(0.75)
        iqr = q3 - q1
        lower = max(q1 - 1.5 * iqr, 0)
        menu_key = menu[0] if isinstance(menu, tuple) else menu
        lower_bounds[menu_key] = lower
    return lower_bounds

#Train
def train_lstm(train_df, use_validation=True, dropout=0.3):
    trained_models = {}

    for store_menu, group in tqdm(train_df.groupby(['영업장명_메뉴명']), desc ='Training LSTM'):
        #시계열 정렬 , preprocessing
        key = store_menu[0] if isinstance(store_menu, tuple) else store_menu
        store_train = group.sort_values('영업일자').copy()
        store_train['영업일자'] = pd.to_datetime(store_train['영업일자'])
        store_train['weekday'] = store_train['영업일자'].dt.dayofweek
        store_train['weekday'] = store_train['weekday'].astype(int)
        store_train['month'] = store_train['영업일자'].dt.month

        store_train['season'] = store_train['month'].map({
            12:0,1:0,2:0, #winter
            3:1,4:1,5:1, #spring
            6:2,7:2,8:2, #summer
            9:3,10:3,11:3 #fall
        })  
        store_train['season'] = store_train['season'].astype(int)

        store_train['month'] /= MONTH_SCALE
        

        #data clipping
        store_train['clipped_SQ'] = clip_iqr(store_train['매출수량'])
        store_train['delta'] = store_train['clipped_SQ'].diff().fillna(0)
        
        #rolling_mean_7
        store_train['rolling_mean_7'] = store_train['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #train/validation split을 안전하게 하기 위해 여유분 데이터를 확보하는 목적 -> MIN_SEQUENCE_COUNT
        if len(store_train) < LOOKBACK + PREDICT + MIN_SEQUENCE_COUNT:
            continue

        #features = ['clipped_SQ','weekday','month','season', 'is_holiday', 'rolling_mean_7','delta_scaled', 'store_id']
        features = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
        scaler = MinMaxScaler()

        ##정규화, 요일정보 
        store_train[['clipped_SQ','rolling_mean_7']] = scaler.fit_transform(store_train[['clipped_SQ', 'rolling_mean_7']])
        scaler_delta = MinMaxScaler()
        store_train[['delta_scaled']] = scaler_delta.fit_transform(store_train[['delta']])


        train_vals = store_train[features].values  # shape: (N, 8)

        # 시퀀스 생성
        X, y, weekday_seqs, season_seqs = [], [], [], []

        for i in range(len(store_train) - LOOKBACK - PREDICT + 1):
            X.append(store_train[features].values[i:i+LOOKBACK])
            y.append(store_train['clipped_SQ'].values[i+LOOKBACK:i+LOOKBACK+PREDICT])
            weekday_seqs.append(store_train['weekday'].values[i:i+LOOKBACK])
            season_seqs.append(store_train['season'].values[i:i+LOOKBACK])

        X = torch.tensor(X).float()
        y = torch.tensor(y).float()

        weekday_seqs = torch.tensor(weekday_seqs).long()
        season_seqs = torch.tensor(season_seqs).long()

        if use_validation:
            # Train/Validation split (기존 방식 유지)
            split_idx = int(len(X) * 0.8)
            X_train, X_val = X[:split_idx], X[split_idx:]
            y_train, y_val = y[:split_idx], y[split_idx:]
            weekday_train, weekday_val = weekday_seqs[:split_idx], weekday_seqs[split_idx:]
            season_train, season_val = season_seqs[:split_idx], season_seqs[split_idx:]
        else:
            # 전체 데이터 학습에 사용
            X_train = X
            y_train = y
            weekday_train = weekday_seqs
            season_train = season_seqs

        X_train, y_train = X_train.to(DEVICE), y_train.to(DEVICE)
        weekday_train, season_train = weekday_train.to(DEVICE), season_train.to(DEVICE)

        if use_validation:
            X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)
            weekday_val, season_val = weekday_val.to(DEVICE), season_val.to(DEVICE)

        model = MultiEmbeddingLSTM(input_dim=len(features), output_dim=PREDICT, dropout=dropout).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        #loss 저장 리스트
        train_losses = []
        val_losses = []

        for epoch in range(EPOCHS):
            model.train()
            total_loss = 0
            idx = torch.randperm(len(X_train))

            for i in range(0, len(X_train), BATCH_SIZE):
                batch_idx = idx[i:i+BATCH_SIZE]
                X_batch = X_train[batch_idx]
                y_batch = y_train[batch_idx]
                weekday_batch = weekday_train[batch_idx]
                season_batch = season_train[batch_idx]

                output = model(X_batch, weekday_batch, season_batch)
                loss = criterion(output, y_batch)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            avg_loss = total_loss / (len(X_train) // BATCH_SIZE + 1)
            train_losses.append(avg_loss)

            if use_validation:
                model.eval()
                with torch.no_grad():
                    val_output = model(X_val, weekday_val, season_val)
                    val_loss = criterion(val_output, y_val).item()
                    val_losses.append(val_loss)

        visualize_loss(train_losses, val_losses if use_validation else None, key, save=True)

        trained_models[store_menu] = {
            'model': model.eval(),
            'scaler': scaler,
            'scaler_delta': scaler_delta,
            'last_sequence': {
                'X': train_vals[-LOOKBACK:],  # 수치 입력
                'weekday': store_train['weekday'].values[-LOOKBACK:],  # 임베딩용
                'season': store_train['season'].values[-LOOKBACK:]
            }
        }

    return trained_models

def visualize_loss(train_losses, val_losses, store_menu, save=False, out_dir="./loss_plots"):
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    if val_losses is not None:
        plt.plot(val_losses, label='Validation Loss')
    plt.title(f"[{store_menu}] Train vs Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    if save:
        os.makedirs(out_dir, exist_ok=True)
        safe_name = re.sub(r'[^\w\-_.]', '_', store_menu)
        path = os.path.join(out_dir, f"{safe_name}.png")
        plt.savefig(path)
    else:
        plt.show()

    plt.close()

#Prediction
def predict_lstm(test_df, trained_models, test_prefix: str, *,
    discontinued: dict[str, str | pd.Timestamp] | None = None,  # <- 추가
    rule: str = 'after',     # 'after' : 단종일자 이후(>) 0, 'on_or_after' : 단종일자 당일 포함(>=) 0
    grace_days: int = 0
    ):            # 유예일 (단종일자 + grace_days 이후부터 0)
    results = []

    cutoff_map = None
    if discontinued is not None:
        def _to_ts(v):
            return v if isinstance(v, pd.Timestamp) else pd.to_datetime(v)
        cutoff_map = {k: _to_ts(v) for k, v in discontinued.items()}
        if grace_days != 0:
            for k in cutoff_map:
                cutoff_map[k] = cutoff_map[k] + pd.Timedelta(days=grace_days)

    for store_menu, store_test in test_df.groupby(['영업장명_메뉴명']):
        key = store_menu
        if key not in trained_models:
            continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']
        scaler_delta = trained_models[key]['scaler_delta']
        

        store_test_sorted = store_test.sort_values('영업일자').copy()
        store_test_sorted['영업일자'] = pd.to_datetime(store_test_sorted['영업일자'])
        store_test_sorted['weekday'] = store_test_sorted['영업일자'].dt.dayofweek.astype(int)
        store_test_sorted['month'] = store_test_sorted['영업일자'].dt.month
        store_test_sorted['season'] = store_test_sorted['month'].map({
            12:0,1:0,2:0,
            3:1,4:1,5:1,
            6:2,7:2,8:2,
            9:3,10:3,11:3
        }).astype(int)
        store_test_sorted['clipped_SQ'] = clip_iqr(store_test_sorted['매출수량'])

        #month 정규화
        store_test_sorted['month'] /= MONTH_SCALE

        # holiday feature 추가
        store_test_sorted = generate_combined_holiday_list(store_test_sorted, solar_md_holidays, lunar_solar_dates)

        # rolling_mean_7 계산
        store_test_sorted['rolling_mean_7'] = store_test_sorted['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #delta
        store_test_sorted['delta'] = store_test_sorted['clipped_SQ'].diff().fillna(0)
        store_test_sorted[['delta_scaled']] = scaler_delta.transform(store_test_sorted[['delta']])


        # feature_cols = ['매출수량','month','is_holiday','rolling_mean_7','delta_scaled']
        # recent_vals = store_test_sorted[feature_cols].values[-LOOKBACK:]

        # 최근 LOOKBACK 개 추출
        if len(store_test_sorted) < LOOKBACK:
            last_seq = trained_models[key]['last_sequence']
            x_input = torch.tensor([last_seq['X']]).float().to(DEVICE)
            weekday_seq = torch.tensor([last_seq['weekday']]).long().to(DEVICE)
            season_seq = torch.tensor([last_seq['season']]).long().to(DEVICE)
            last_obs_date = pd.to_datetime(last_seq['영업일자'].max())
        else:
            recent_vals = store_test_sorted.iloc[-LOOKBACK:].copy()

            # clipped_SQ 생성 및 정규화
            recent_vals['clipped_SQ'] = clip_iqr(recent_vals['매출수량'])
            recent_vals['rolling_mean_7'] = recent_vals['clipped_SQ'].rolling(window=7, min_periods=1).mean()
            recent_vals['delta'] = recent_vals['clipped_SQ'].diff().fillna(0)
            recent_vals[['clipped_SQ', 'rolling_mean_7']] = scaler.transform(recent_vals[['clipped_SQ', 'rolling_mean_7']])
            recent_vals[['delta_scaled']] = scaler_delta.transform(recent_vals[['delta']])

            feature_cols = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
            x_input = torch.tensor([recent_vals[feature_cols].values]).float().to(DEVICE)
            weekday_seq = torch.tensor([recent_vals['weekday'].values]).long().to(DEVICE)
            season_seq = torch.tensor([recent_vals['season'].values]).long().to(DEVICE)
            last_obs_date = pd.to_datetime(recent_vals['영업일자'].max())


        # 예측
        with torch.no_grad():
            pred_scaled = model(x_input, weekday_seq, season_seq).squeeze().cpu().numpy()


        # 역정규화 및 하한 클리핑
        restored = []
        for i in range(PREDICT):
            val = pred_scaled[i]
            dummy_input = np.zeros((1, 2))
            dummy_input[0, 0] = val
            restored_val = scaler.inverse_transform(dummy_input)[0][0]
            #restored.append(max(restored_val, lower_bound))
            restored.append(max(restored_val, 1))  # 또는 lower_bound

        # ----- (B) 단종 처리: 예측 구간 실제 날짜와 비교 -----
        # 예측 구간의 "실제 달력 날짜" 생성 (last_obs_date 다음날부터 PREDICT일)
        horizon_dates = pd.date_range(start=last_obs_date + pd.Timedelta(days=1),
                                      periods=PREDICT, freq='D')

        if cutoff_map is not None:
            cutoff = cutoff_map.get(key, None)
            if cutoff is not None:
                if rule == 'on_or_after':
                    zero_mask = horizon_dates >= cutoff
                else:  # 'after'
                    zero_mask = horizon_dates > cutoff
                vals_real = np.where(zero_mask, 0.0, vals_real)


        # 예측일자: TEST_00+1일 ~ TEST_00+7일
        # 결과 저장
        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]
        for d, val in zip(pred_dates, restored):
            results.append({
                '영업일자': d,
                '영업장명_메뉴명': store_menu[0],
                '매출수량': val
            })
    

    return pd.DataFrame(results)

def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    # (영업일자, 메뉴) → 매출수량 딕셔너리로 변환
    pred_dict = dict(zip(
        zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']),
        pred_df['매출수량']
    ))

    final_df = sample_submission.copy()

    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:  # 메뉴명들
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)

    return final_df

# %%
# 학습
#Data load
train = pd.read_csv('./train/train.csv')
train = generate_combined_holiday_list(train, solar_md_holidays, lunar_solar_dates)
trained_models = train_lstm(train, use_validation=False, dropout=0.1)
# Out:
# Training LSTM:   0%|          | 0/193 [00:00<?, ?it/s]/var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/3812063699.py:295: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   X = torch.tensor(X).float()
# Training LSTM: 100%|██████████| 193/193 [21:24<00:00,  6.65s/it]

# %%
all_preds = []

# 모든 test_*.csv 순회
test_files = sorted(glob.glob('./test/TEST_*.csv'))
df = pd.read_csv('./train/train.csv')
lower_bound_dict = compute_iqr_lower_bounds(df)
for path in test_files:
    test_df = pd.read_csv(path)
    # 파일명에서 접두어 추출 (예: TEST_00)
    filename = os.path.basename(path)
    test_prefix = re.search(r'(TEST_\d+)', filename).group(1)

    pred_df = predict_lstm(test_df, trained_models, test_prefix,
        discontinued=DISCONTINUED,
        rule='after',      # 단종일 "이후" 0
        grace_days=0       # 유예일 없으면 0
    )
    all_preds.append(pred_df)
    
full_pred_df = pd.concat(all_preds, ignore_index=True)

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
submission = convert_to_submission_format(full_pred_df, sample_submission)
submission.to_csv('./Prediction/sample00.csv', index=False, encoding='utf-8-sig')
result = pd.read_csv('./Prediction/sample00.csv')
display(result.head())
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.372346103191376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.697494506835938' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0859081149101253' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.1499374508857727' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9771116971969604' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0865922272205353' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5115106105804443' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.827775448560715' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7336392402648926' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.77793212980032' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.223559776321054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.9116609543561935' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.477595239877701' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.939477175474167' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3954362124204636' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.940297707915306' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.258041113615036' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.393995106220245' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.372416853904724' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1305982917547226' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6855598986148834' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.883768543601036' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.782080486416817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0194803178310394' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.029112666845322' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.846916437149048' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.826488763093948' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.442518174648285' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.061707451939583' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.119343727827072' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2536709010601044' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.891408920288086' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.395126581192017' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.469304233789444' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.643936023116112' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.805335097014904' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5723039507865906' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.091479152441025' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7281787395477295' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3110630363225937' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5450798869132996' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.476798444986343' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4379159547388554' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2372636198997498' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8409299850463867' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8215273320674896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0264263302087784' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.379868984222412' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3576040044426918' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.724313735961914' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.731998771429062' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8539544939994812' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.417218059301376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.11551296710968' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.916023880243301' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1024489998817444' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.402581676840782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '142.8605206310749' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4876144528388977' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.419876217842102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5410715341567993' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.142974153161049' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2822706997394562' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.62559050321579' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4775440096855164' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.766306772828102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8088163435459137' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4816484600305557' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1056878417730331' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5411944687366486' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.109977811574936' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6627347469329834' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.067475598305464' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.512680443003774' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.405555859208107' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.687022607773542' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.284699331969023' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.595095232129097' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.909148082137108' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.356031894683838' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.9480874836444855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6636843755841255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.941974930465221' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.8357834815979' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.719896352849902' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.546082979533821' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.465229541063309' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.077177475206552' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.403030269779265' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4592928923666477' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.886578887701035' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.643807401880624' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0361567195504904' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.4466560184955597' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5853754617273808' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.754692360758781' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.57703049480915' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.123931884765625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.95788785815239' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.118187628686428' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.03978443145752' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.696656923741102' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.149515926837921' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '45.62373664230108' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.329470589756966' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.918536636978388' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '45.78024065122008' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5836697090417147' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.127777200192213' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.391098648309708' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7524674311280255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.060575023293495' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.3176390854641795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.107714436948299' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.094059793278577' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0515902191400528' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '34.71224308013917' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1384347081184387' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '25.740566849708557' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1006759852170944' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0113815069198608' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4884519577026367' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0738193988800049' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0833632946014404' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2291748076677322' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0446178913116455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# ...
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1830845475196838' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2370358407497406' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3277392089366913' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2456317991018295' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.102757528424263' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.287112534046173' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5707650780677795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2890031933784485' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3036012649536133' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1607509851455688' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1278101205825806' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2754514813423157' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.650731086730957' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1546822637319565' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.096761018037796' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.078108325600624' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.531117856502533' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4914271235466003' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.110285110771656' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2874847650527954' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0815965384244919' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0005340576171875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.042192280292511' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0726886987686157' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.140738844871521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6071420907974243' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '28.466305136680603' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.029594864696264' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.381742000579834' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '38.699654936790466' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6724106073379517' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.565527260303497' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.85454273223877' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1310964077711105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0749899595975876' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_2580/2810635526.py:538: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1515379697084427' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
#          영업일자  느티나무 셀프BBQ_1인 수저세트  느티나무 셀프BBQ_BBQ55(단체)  \
# 0  TEST_00+1일            4.372346              1.000000
# 1  TEST_00+2일            1.410438             16.391099
# 2  TEST_00+3일            1.925196             17.960576
# 3  TEST_00+4일            3.302394             39.169170
# 4  TEST_00+5일            5.541323             54.775810
#
#    느티나무 셀프BBQ_대여료 30,000원  느티나무 셀프BBQ_대여료 60,000원  느티나무 셀프BBQ_대여료 90,000원  \
# 0                8.697495                3.085908                     1.0
# 1                1.676109                1.000000                     1.0
# 2                2.507252                1.292206                     1.0
# 3                2.061698                1.604371                     1.0
# 4                1.908912                1.494736                     1.0
#
#    느티나무 셀프BBQ_본삼겹 (단품,실내)  느티나무 셀프BBQ_스프라이트 (단체)  느티나무 셀프BBQ_신라면  \
# 0                     1.0               1.000000        2.149937
# 1                     1.0               3.752467        1.215982
# 2                     1.0               1.731769        1.000000
# 3                     1.0               5.084477        1.000000
# 4                     1.0              11.999178        1.000000
#
#    느티나무 셀프BBQ_쌈야채세트  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  화담숲주막_찹쌀식혜  화담숲주막_콜라  \
# 0          1.977112  ...    10.118188      23.039784   11.696657  9.149516
# 1          1.000000  ...     2.791408       7.147304    3.593304  4.334218
# 2          1.000000  ...     2.434437       5.499993    3.110316  2.261264
# 3          1.000000  ...     4.565908      11.571920    3.042215  1.286714
# 4          1.000000  ...     3.319329       8.431218    3.692081  4.780386
#
#    화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  \
# 0   45.623737     17.329471         4.918537        45.780241        3.583670
# 1   15.440493      9.154857         4.245999         9.731722        2.217496
# 2   15.949803      7.936536         4.355130        32.938506        2.249970
# 3   18.584067      6.696788         4.273219        15.251455        2.393341
# 4   17.706174      5.732727         5.125171        20.980341        2.093925
#
#    화담숲카페_현미뻥스크림
# 0     14.127777
# 1      3.779385
# 2      1.000000
# 3      1.000000
# 4      1.000000
#
# [5 rows x 194 columns]
