# %%
import os
import random
import glob
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from tqdm import tqdm

import matplotlib.pyplot as plt
from korean_lunar_calendar import KoreanLunarCalendar


plt.rcParams['font.family'] = 'AppleGothic'  # macOS


#Fixed Random Seed  & Setting Hyperparameter
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(42)

LOOKBACK, PREDICT, BATCH_SIZE, EPOCHS = 28, 7, 16, 50
DEVICE = torch.device("cpu")
MONTH_SCALE = 12
SEASON_SCALE = 3 
#winter : 0
#spring : 1
#summer : 2
#fall : 3
MIN_SEQUENCE_COUNT = 10

def get_lunar_to_solar(years, lunar_month, lunar_day, span=1):
    calendar = KoreanLunarCalendar()
    dates = []
    for year in years:
        for offset in range(-span, span+1):
            try:
                calendar.setLunar(year, lunar_month, lunar_day + offset, False)
                dates.append(calendar.SolarIsoFormat())
            except:
                pass  # 예외 처리: 음력 마지막날 초과
    return dates
# 예시: 2023 ~ 2025
years = [2023, 2024, 2025]
lunar_solar_dates = []
lunar_solar_dates += get_lunar_to_solar(years, 1, 1, span=1)   # 설날 ±1
lunar_solar_dates += get_lunar_to_solar(years, 8, 15, span=1)  # 추석 ±1

solar_md_holidays = [
    (1, 1),   # 신정
    (3, 1),   # 삼일절
    (5, 5),   # 어린이날
    (6, 6),   # 현충일
    (8, 15),  # 광복절
    (10, 3),  # 개천절
    (10, 9),  # 한글날
    (12, 25), # 크리스마스
]

def generate_combined_holiday_list(df, solar_md_list, lunar_solar_list):
    df = df.copy()
    df['영업일자'] = pd.to_datetime(df['영업일자'])

    # 양력 기반 holiday 판별
    df['is_solar_holiday'] = df['영업일자'].apply(
        lambda x: (x.month, x.day) in solar_md_list
    )

    # 음력 변환된 holiday 포함
    lunar_set = set(pd.to_datetime(lunar_solar_list))
    df['is_lunar_holiday'] = df['영업일자'].isin(lunar_set)

    # 최종 통합
    df['is_holiday'] = (df['is_solar_holiday'] | df['is_lunar_holiday']).astype(int)
    df = df.drop(columns=['is_solar_holiday', 'is_lunar_holiday'])
    return df

def remove_leading_zeros_before_sales(df, min_zero_days=90):
    """
    매출 시작 전 연속된 0이 일정 기간 이상이면, 그 전 구간은 제거
    """
    sales_started = df['매출수량'] > 0
    if not sales_started.any():
        return df  # 매출이 전혀 없는 경우 그대로 반환

    first_sale_idx = sales_started.idxmax()

    # 매출 시작 전 구간이 충분히 긴 0으로 구성되어 있다면 제거
    df_before = df.loc[:first_sale_idx - 1]
    if len(df_before) >= min_zero_days and (df_before['매출수량'] == 0).all():
        return df.loc[first_sale_idx:]  # 매출 시작부터 반환
    else:
        return df  # 그대로 반환

def filter_all_menus_by_leading_zeros(train_df, min_zero_days=90):
    """
    모든 메뉴에 대해 remove_leading_zeros_before_sales 함수 적용
    """
    filtered_df = (
        train_df.groupby('영업장명_메뉴명')
        .apply(lambda g: remove_leading_zeros_before_sales(g, min_zero_days))
        .reset_index(drop=True)
    )
    return filtered_df

#Data load
train = pd.read_csv('./train/train.csv')
train = generate_combined_holiday_list(train, solar_md_holidays, lunar_solar_dates)
train = filter_all_menus_by_leading_zeros(train, min_zero_days=90)

#Define Model
class MultiOutputLSTM(nn.Module):
    def __init__(self, input_dim=7, hidden_dim=64, num_layers=2, output_dim=7):
        super(MultiOutputLSTM, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        out, _ = self.lstm(x)
        return self.fc(out[:, -1, :])  # (B, output_dim)

def clip_iqr(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    upper = q3 + 1.5 * iqr
    return np.clip(series, None, upper)

def compute_iqr_lower_bounds(train_df):
    lower_bounds = {}
    for menu, group in train_df.groupby('영업장명_메뉴명'):
        q1 = group['매출수량'].quantile(0.25)
        q3 = group['매출수량'].quantile(0.75)
        iqr = q3 - q1
        lower = max(q1 - 1.5 * iqr, 0)
        menu_key = menu[0] if isinstance(menu, tuple) else menu
        lower_bounds[menu_key] = lower
    return lower_bounds

#Train
def train_lstm(train_df):
    trained_models = {}

    for store_menu, group in tqdm(train_df.groupby(['영업장명_메뉴명']), desc ='Training LSTM'):
        #시계열 정렬 , preprocessing
        key = store_menu[0] if isinstance(store_menu, tuple) else store_menu
        store_train = group.sort_values('영업일자').copy()
        store_train['영업일자'] = pd.to_datetime(store_train['영업일자'])
        store_train['weekday'] = store_train['영업일자'].dt.dayofweek
        store_train['month'] = store_train['영업일자'].dt.month
        store_train['season'] = store_train['month'].map({
            12:0,1:0,2:0, #winter
            3:1,4:1,5:1, #spring
            6:2,7:2,8:2, #summer
            9:3,10:3,11:3 #fall
        })  
        #month,season normalize
        store_train['month'] /= MONTH_SCALE
        store_train['season'] /= SEASON_SCALE
        #rolling_mean_7
        store_train['rolling_mean_7'] = store_train['매출수량'].rolling(window=7, min_periods=1).mean()

        #data clipping
        store_train['clipped_SQ'] = clip_iqr(store_train['매출수량'])
        store_train['delta'] = store_train['clipped_SQ'].diff().fillna(0)
        
        #train/validation split을 안전하게 하기 위해 여유분 데이터를 확보하는 목적 -> MIN_SEQUENCE_COUNT
        if len(store_train) < LOOKBACK + PREDICT + MIN_SEQUENCE_COUNT:
            continue

        features = ['clipped_SQ','weekday','month','season', 'is_holiday', 'rolling_mean_7','delta_scaled']
        scaler = MinMaxScaler()
        ##정규화, 요일정보 
        store_train[['clipped_SQ','rolling_mean_7']] = scaler.fit_transform(store_train[['clipped_SQ', 'rolling_mean_7']])
        scaler_delta = MinMaxScaler()
        store_train['delta_scaled'] = scaler_delta.fit_transform(store_train[['delta']])
        train_vals = store_train[features].values  # shape: (N, 6)

        # 시퀀스 생성
        X, y = [], []
        for i in range(len(train_vals) - LOOKBACK - PREDICT + 1):
            X.append(train_vals[i:i + LOOKBACK])
            y.append(train_vals[i + LOOKBACK:i + LOOKBACK + PREDICT, 0])  # 매출수량만 예측

        X = torch.tensor(X).float()
        y = torch.tensor(y).float()

        # ✅ Train/Validation split (80% / 20%)
        split_idx = int(len(X) * 0.8)
        X_train, X_val = X[:split_idx], X[split_idx:]
        y_train, y_val = y[:split_idx], y[split_idx:]

        #X_train, y_train = X_train.to(DEVICE), y_train.to(DEVICE)
        X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)

        model = MultiOutputLSTM(input_dim=7, output_dim=PREDICT).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        #loss 저장 리스트
        train_losses = []
        val_losses = []

        model.train()
        for epoch in range(EPOCHS):
            model.train()
            total_loss = 0  # 전체 에폭의 평균 loss 계산용
            idx = torch.randperm(len(X_train))  # 데이터 섞기
            
            for i in range(0, len(X_train), BATCH_SIZE):
                batch_idx = idx[i:i+BATCH_SIZE]
                X_batch = X_train[batch_idx].to(DEVICE)
                y_batch = y_train[batch_idx].to(DEVICE)
                
                output = model(X_batch)
                loss = criterion(output, y_batch)
                
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                total_loss += loss.item()
            
            avg_loss = total_loss / (len(X_train) // BATCH_SIZE + 1)
            
            train_losses.append(avg_loss)  # loss 기록
            # 검증 손실 계산
            model.eval()
            with torch.no_grad():
                val_output = model(X_val)
                val_loss = criterion(val_output, y_val).item()
                val_losses.append(val_loss)

        #loss 시각화
        visualize_loss(train_losses, val_losses, key, save=True)

        trained_models[store_menu] = {
            'model': model.eval(),
            'scaler': scaler,
            'scaler_delta': scaler_delta,
            'last_sequence': train_vals[-LOOKBACK:]  # (28, 7)
        }

    return trained_models

def visualize_loss(train_losses, val_losses, store_menu, save=False, out_dir="./loss_plots"):
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title(f"[{store_menu}] Train vs Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    
    if save:
        os.makedirs(out_dir, exist_ok=True)
        safe_name = re.sub(r'[^\w\-_.]', '_', store_menu)  # 파일명 안전하게 처리
        path = os.path.join(out_dir, f"{safe_name}.png")
        plt.savefig(path)
    else:
        plt.show()

    plt.close()

#Prediction
def predict_lstm(test_df, trained_models, test_prefix: str, lower_bound_dict: dict):
    results = []

    for store_menu, store_test in test_df.groupby(['영업장명_메뉴명']):
        key = store_menu
        if key not in trained_models:
            continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']
        scaler_delta = trained_models[key]['scaler_delta']

        store_test_sorted = store_test.sort_values('영업일자')
        store_test_sorted['영업일자'] = pd.to_datetime(store_test_sorted['영업일자'])
        store_test_sorted['weekday'] = store_test_sorted['영업일자'].dt.dayofweek
        store_test_sorted['month'] = store_test_sorted['영업일자'].dt.month
        store_test_sorted['season'] = store_test_sorted['month'].map({
            12:0,1:0,2:0, #winter
            3:1,4:1,5:1, #spring
            6:2,7:2,8:2, #summer
            9:3,10:3,11:3 #fall
        })  

        #month, season 정규화
        store_test_sorted['month'] /= MONTH_SCALE
        store_test_sorted['season'] /= SEASON_SCALE
        # holiday feature 추가
        store_test_sorted = generate_combined_holiday_list(store_test_sorted, solar_md_holidays, lunar_solar_dates)

        # rolling_mean_7 계산
        store_test_sorted['rolling_mean_7'] = store_test_sorted['매출수량'].rolling(window=7, min_periods=1).mean()

        #delta
        store_test_sorted['delta'] = store_test_sorted['매출수량'].diff().fillna(0)
        store_test_sorted['delta_scaled'] = scaler_delta.transform(store_test_sorted[['delta']])

        feature_cols = ['매출수량','weekday','month','season','is_holiday','rolling_mean_7','delta_scaled']
        recent_vals = store_test_sorted[feature_cols].values[-LOOKBACK:]

        if len(recent_vals) < LOOKBACK:
            recent_vals = trained_models[key]['last_sequence']  # (28, 7)
        
        # 매출수량만 정규화
        recent_vals[:, [0, 5]] = scaler.transform(recent_vals[:, [0, 5]])
        recent_vals[:, 6] = scaler_delta.transform(recent_vals[:, [6]])[:, 0]  # delta_scaled

        x_input = torch.tensor([recent_vals]).float().to(DEVICE)

        with torch.no_grad():
            pred_scaled = model(x_input).squeeze().cpu().numpy()

        lower_bound = lower_bound_dict.get(key, 0)

        # 역변환
        restored = []
        for i in range(PREDICT):
            val = pred_scaled[i]
            dummy_input = np.zeros((1, 2))
            dummy_input[0, 0] = val  # 매출수량만 역변환
            restored_val = scaler.inverse_transform(dummy_input)[0][0]
            #실제 기반 lower_bound
            #restored.append(max(restored_val, lower_bound))
            restored.append(max(restored_val, 1))



        # 예측일자: TEST_00+1일 ~ TEST_00+7일
        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]

        for d, val in zip(pred_dates, restored):
            results.append({
                '영업일자': d,
                '영업장명_메뉴명': store_menu[0],
                '매출수량': val
            })
    

    return pd.DataFrame(results)

def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    # (영업일자, 메뉴) → 매출수량 딕셔너리로 변환
    pred_dict = dict(zip(
        zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']),
        pred_df['매출수량']
    ))

    final_df = sample_submission.copy()

    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:  # 메뉴명들
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)

    return final_df
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:111: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: remove_leading_zeros_before_sales(g, min_zero_days))

# %%
# 학습
trained_models = train_lstm(train)
# Out:
# Training LSTM: 100%|██████████| 193/193 [23:06<00:00,  7.19s/it]

# %%
all_preds = []

# 모든 test_*.csv 순회
test_files = sorted(glob.glob('./test/TEST_*.csv'))
df = pd.read_csv('./train/train.csv')
lower_bound_dict = compute_iqr_lower_bounds(df)
for path in test_files:
    test_df = pd.read_csv(path)
    # 파일명에서 접두어 추출 (예: TEST_00)
    filename = os.path.basename(path)
    test_prefix = re.search(r'(TEST_\d+)', filename).group(1)

    pred_df = predict_lstm(test_df, trained_models, test_prefix, lower_bound_dict)
    all_preds.append(pred_df)
    
full_pred_df = pd.concat(all_preds, ignore_index=True)
# Out:
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /Users/widohun/tf_env/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
submission = convert_to_submission_format(full_pred_df, sample_submission)
submission.to_csv('./Prediction/8th.csv', index=False, encoding='utf-8-sig')
result = pd.read_csv('./Prediction/8th.csv')
display(result.head())
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.521210074424744' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.201359748840332' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.617996215820312' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4274446666240692' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.12299507111311' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4667929336428642' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1080919206142426' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.067725419998169' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4417430013418198' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.183856904506683' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.086446017026901' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.159802168607712' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.428966537117958' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.065563894808292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.594300150871277' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2769637182354927' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8151011317968369' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2493830919265747' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8216992914676666' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '38.07449150085449' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.949755847454071' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '28.291086852550507' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.770360223948956' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0395681858062744' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9707579612731934' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1054744124412537' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8376805782318115' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.697275161743164' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.385012775659561' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.634676471352577' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.794100269675255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7144140601158142' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.7672794461250305' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5607011318206787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.31204605102539' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.802710592746735' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '31.393316611647606' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.029492065310478' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.104349583387375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4768362045288086' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.107444852590561' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1880423426628113' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.823218822479248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.685258060693741' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.198963940143585' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6421867161989212' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.550006806850433' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5857070684432983' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1296746134757996' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9705481827259064' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4404511451721191' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.963046699762344' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.598219871520996' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7344340682029724' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.716417610645294' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0673660784959793' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '49.40887498855591' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.127314746379852' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3949839770793915' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.239161044359207' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '144.33030411601067' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.1764081455767155' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.810243606567383' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6934609413146973' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.73084656894207' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9899832606315613' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6780902445316315' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.1410618722438812' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3861548900604248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8198966979980469' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0369306802749634' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.8372922539711' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.115507367067039' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.589898608624935' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.498374581336975' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.236036060377955' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.828249195590615' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.393795728683471' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.90685943607241' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3446056842803955' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.283728212118149' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5382149666547775' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.036479204893112' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8773390650749207' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.88659773254767' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.125135615700855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.724849924445152' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.40691885538399' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5966918654739857' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9064794573932886' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.804538890719414' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.251400131732227' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.364252856001258' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1193268932402134' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.450393609702587' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6428995802998543' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.43585243821144' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.627973556518555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.51705526560545' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.570252478122711' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.938578858971596' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.53640733845532' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.601855352520943' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '51.730780396610506' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.22377710044384' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7082904018461704' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.20906845666468' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.910688871517777' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.924765944480896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.103739504702389' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.211890295147896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.854112247470766' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.179660886526108' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2127116322517395' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.39404249191284' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.39667463302613' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.6177104860544205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.6658390909433365' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3841534834355116' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0854845121502876' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0746368020772934' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.406346745789055' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1387640237808228' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3523061573505402' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1139583960175514' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6371777653694153' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# ...
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3971778750419617' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.524386703968048' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.730249971151352' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5783999860286713' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.216742813587189' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.042961835861206' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1177627742290497' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3166899979114532' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0288456827402115' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3526464998722076' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.167525053024292' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7864525988698006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.13664910197258' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.022783875465393' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3877692818641663' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6479963064193726' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3712158799171448' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3797357678413391' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6012580096721651' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1801306996494532' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1396710574626923' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.030629500746727' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.413073182106018' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '36.30546122789383' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.160866022109985' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.7043339610099792' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40.76145529747009' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5003509819507599' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '38.32368850708008' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.889429420232773' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.620862483978271' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4517909288406372' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2297385185956955' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0907456278800964' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_30980/3264858307.py:368: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7389138787984848' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
#          영업일자  느티나무 셀프BBQ_1인 수저세트  느티나무 셀프BBQ_BBQ55(단체)  \
# 0  TEST_00+1일            6.521210              1.000000
# 1  TEST_00+2일            1.000000              1.000000
# 2  TEST_00+3일            1.021494              4.617710
# 3  TEST_00+4일            4.683807             38.123369
# 4  TEST_00+5일           11.476449             86.526394
#
#    느티나무 셀프BBQ_대여료 30,000원  느티나무 셀프BBQ_대여료 60,000원  느티나무 셀프BBQ_대여료 90,000원  \
# 0               10.201360                4.617996                1.427445
# 1                2.555326                1.387922                1.000000
# 2                3.673095                1.196251                1.000000
# 3                2.358593                1.114210                1.000000
# 4                3.219666                1.278076                1.000000
#
#    느티나무 셀프BBQ_본삼겹 (단품,실내)  느티나무 셀프BBQ_스프라이트 (단체)  느티나무 셀프BBQ_신라면  \
# 0                     1.0               1.122995        1.466793
# 1                     1.0               5.262598        1.355530
# 2                     1.0               2.409015        1.000000
# 3                     1.0               4.051581        3.292999
# 4                     1.0              11.196315        6.608906
#
#    느티나무 셀프BBQ_쌈야채세트  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  화담숲주막_찹쌀식혜  화담숲주막_콜라  \
# 0               1.0  ...    11.570252      21.938579   19.536407  9.601855
# 1               1.0  ...     5.794386      15.566008    3.979238  7.993600
# 2               1.0  ...     3.820545       7.184070    9.062696  5.683325
# 3               1.0  ...     5.100224       3.907532    9.894204  4.908697
# 4               1.0  ...     7.777095       5.807018   12.277856  7.369286
#
#    화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  \
# 0   51.730780     27.223777         3.708290        21.209068        5.910689
# 1    7.812460     16.519159         3.022334        11.977704        6.049024
# 2    9.682637     14.942040         3.123753        17.538267        4.518522
# 3   20.968450     14.686590         3.540440        14.412822        3.796835
# 4   24.457144     11.276521         3.171910        12.621660        6.456488
#
#    화담숲카페_현미뻥스크림
# 0     12.924766
# 1      4.920019
# 2      4.710245
# 3      4.924147
# 4      4.068885
#
# [5 rows x 194 columns]
