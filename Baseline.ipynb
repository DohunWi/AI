# %%
#version_05
import os
import random
import glob
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from tqdm import tqdm

import matplotlib.pyplot as plt
from korean_lunar_calendar import KoreanLunarCalendar


plt.rcParams['font.family'] = 'AppleGothic'  # macOS


#Fixed Random Seed  & Setting Hyperparameter
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(42)

LOOKBACK, PREDICT, BATCH_SIZE, EPOCHS = 28, 7, 16, 50
DEVICE = torch.device("cpu")
MONTH_SCALE = 12

MIN_SEQUENCE_COUNT = 10

def get_lunar_to_solar(years, lunar_month, lunar_day, span=1):
    calendar = KoreanLunarCalendar()
    dates = []
    for year in years:
        for offset in range(-span, span+1):
            try:
                calendar.setLunar(year, lunar_month, lunar_day + offset, False)
                dates.append(calendar.SolarIsoFormat())
            except:
                pass  # 예외 처리: 음력 마지막날 초과
    return dates
# 예시: 2023 ~ 2025
years = [2023, 2024, 2025]
lunar_solar_dates = []
lunar_solar_dates += get_lunar_to_solar(years, 1, 1, span=1)   # 설날 ±1
lunar_solar_dates += get_lunar_to_solar(years, 8, 15, span=1)  # 추석 ±1

solar_md_holidays = [
    (1, 1),   # 신정
    (3, 1),   # 삼일절
    (5, 5),   # 어린이날
    (6, 6),   # 현충일
    (8, 15),  # 광복절
    (10, 3),  # 개천절
    (10, 9),  # 한글날
    (12, 25), # 크리스마스
]

def generate_combined_holiday_list(df, solar_md_list, lunar_solar_list):
    df = df.copy()
    df['영업일자'] = pd.to_datetime(df['영업일자'])

    # 양력 기반 holiday 판별
    df['is_solar_holiday'] = df['영업일자'].apply(
        lambda x: (x.month, x.day) in solar_md_list
    )

    # 음력 변환된 holiday 포함
    lunar_set = set(pd.to_datetime(lunar_solar_list))
    df['is_lunar_holiday'] = df['영업일자'].isin(lunar_set)

    # 최종 통합
    df['is_holiday'] = (df['is_solar_holiday'] | df['is_lunar_holiday']).astype(int)
    df = df.drop(columns=['is_solar_holiday', 'is_lunar_holiday'])
    return df

def remove_leading_zeros_before_sales(df, min_zero_days=90):
    """
    매출 시작 전 연속된 0이 일정 기간 이상이면, 그 전 구간은 제거
    """
    sales_started = df['매출수량'] > 0
    if not sales_started.any():
        return df  # 매출이 전혀 없는 경우 그대로 반환

    first_sale_idx = sales_started.idxmax()

    # 매출 시작 전 구간이 충분히 긴 0으로 구성되어 있다면 제거
    df_before = df.loc[:first_sale_idx - 1]
    if len(df_before) >= min_zero_days and (df_before['매출수량'] == 0).all():
        return df.loc[first_sale_idx:]  # 매출 시작부터 반환
    else:
        return df  # 그대로 반환

def filter_all_menus_by_leading_zeros(train_df, min_zero_days=90):
    """
    모든 메뉴에 대해 remove_leading_zeros_before_sales 함수 적용
    """
    filtered_df = (
        train_df.groupby('영업장명_메뉴명')
        .apply(lambda g: remove_leading_zeros_before_sales(g, min_zero_days))
        .reset_index(drop=True)
    )
    return filtered_df

#Data load
train = pd.read_csv('./train/train.csv')
train = generate_combined_holiday_list(train, solar_md_holidays, lunar_solar_dates)
train = filter_all_menus_by_leading_zeros(train, min_zero_days=90)

#Define Model
class MultiEmbeddingLSTM(nn.Module):
    def __init__(
        self,
        input_dim,                  # 수치 feature 수
        hidden_dim=64,
        num_layers=2,
        output_dim=7,
        num_weekdays=7,
        weekday_embed_dim=3,
        num_seasons=4,
        season_embed_dim=2,
        dropout=0.3
    ):
        super().__init__()

        # 임베딩
        self.weekday_embedding = nn.Embedding(num_weekdays, weekday_embed_dim)
        self.season_embedding = nn.Embedding(num_seasons, season_embed_dim)

        # LayerNorm for embedding
        self.weekday_norm = nn.LayerNorm(weekday_embed_dim)
        self.season_norm = nn.LayerNorm(season_embed_dim)

        # Dropout after embedding
        self.embedding_dropout = nn.Dropout(dropout)

        total_input_dim = input_dim + weekday_embed_dim + season_embed_dim

        # LSTM
        self.lstm = nn.LSTM(total_input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)

        # LSTM output dropout
        self.post_lstm_dropout = nn.Dropout(dropout)

        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, weekday_ids, season_ids):
        """
        x: (B, T, input_dim)
        weekday_ids: (B, T)
        season_ids: (B, T)
        """
        weekday_embed = self.weekday_embedding(weekday_ids)      # (B, T, D2)
        season_embed = self.season_embedding(season_ids)         # (B, T, D3)

        # 정규화
        weekday_embed = self.weekday_norm(weekday_embed)
        season_embed = self.season_norm(season_embed)

        x_concat = torch.cat([x, weekday_embed, season_embed], dim=-1)  # (B, T, total_dim)
        x_concat = self.embedding_dropout(x_concat)

        out, _ = self.lstm(x_concat)
        out = self.post_lstm_dropout(out)

        return self.fc(out[:, -1, :])
    
def clip_iqr(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    upper = q3 + 1.5 * iqr
    return np.clip(series, None, upper)

def compute_iqr_lower_bounds(train_df):
    lower_bounds = {}
    for menu, group in train_df.groupby('영업장명_메뉴명'):
        q1 = group['매출수량'].quantile(0.25)
        q3 = group['매출수량'].quantile(0.75)
        iqr = q3 - q1
        lower = max(q1 - 1.5 * iqr, 0)
        menu_key = menu[0] if isinstance(menu, tuple) else menu
        lower_bounds[menu_key] = lower
    return lower_bounds

#Train
def train_lstm(train_df, use_validation=True, dropout=0.3):
    trained_models = {}

    for store_menu, group in tqdm(train_df.groupby(['영업장명_메뉴명']), desc ='Training LSTM'):
        #시계열 정렬 , preprocessing
        key = store_menu[0] if isinstance(store_menu, tuple) else store_menu
        store_train = group.sort_values('영업일자').copy()
        store_train['영업일자'] = pd.to_datetime(store_train['영업일자'])
        store_train['weekday'] = store_train['영업일자'].dt.dayofweek
        store_train['weekday'] = store_train['weekday'].astype(int)
        store_train['month'] = store_train['영업일자'].dt.month

        store_train['season'] = store_train['month'].map({
            12:0,1:0,2:0, #winter
            3:1,4:1,5:1, #spring
            6:2,7:2,8:2, #summer
            9:3,10:3,11:3 #fall
        })  
        store_train['season'] = store_train['season'].astype(int)

        store_train['month'] /= MONTH_SCALE
        


        #data clipping
        store_train['clipped_SQ'] = clip_iqr(store_train['매출수량'])
        store_train['delta'] = store_train['clipped_SQ'].diff().fillna(0)
        
        #rolling_mean_7
        store_train['rolling_mean_7'] = store_train['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #train/validation split을 안전하게 하기 위해 여유분 데이터를 확보하는 목적 -> MIN_SEQUENCE_COUNT
        if len(store_train) < LOOKBACK + PREDICT + MIN_SEQUENCE_COUNT:
            continue

        #features = ['clipped_SQ','weekday','month','season', 'is_holiday', 'rolling_mean_7','delta_scaled', 'store_id']
        features = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
        scaler = MinMaxScaler()

        ##정규화, 요일정보 
        store_train[['clipped_SQ','rolling_mean_7']] = scaler.fit_transform(store_train[['clipped_SQ', 'rolling_mean_7']])
        scaler_delta = MinMaxScaler()
        store_train[['delta_scaled']] = scaler_delta.fit_transform(store_train[['delta']])


        train_vals = store_train[features].values  # shape: (N, 8)

        # 시퀀스 생성
        X, y, weekday_seqs, season_seqs = [], [], [], []

        for i in range(len(store_train) - LOOKBACK - PREDICT + 1):
            X.append(store_train[features].values[i:i+LOOKBACK])
            y.append(store_train['clipped_SQ'].values[i+LOOKBACK:i+LOOKBACK+PREDICT])
            weekday_seqs.append(store_train['weekday'].values[i:i+LOOKBACK])
            season_seqs.append(store_train['season'].values[i:i+LOOKBACK])

        X = torch.tensor(X).float()
        y = torch.tensor(y).float()

        weekday_seqs = torch.tensor(weekday_seqs).long()
        season_seqs = torch.tensor(season_seqs).long()

        if use_validation:
            # Train/Validation split (기존 방식 유지)
            split_idx = int(len(X) * 0.8)
            X_train, X_val = X[:split_idx], X[split_idx:]
            y_train, y_val = y[:split_idx], y[split_idx:]
            weekday_train, weekday_val = weekday_seqs[:split_idx], weekday_seqs[split_idx:]
            season_train, season_val = season_seqs[:split_idx], season_seqs[split_idx:]
        else:
            # 전체 데이터 학습에 사용
            X_train = X
            y_train = y
            weekday_train = weekday_seqs
            season_train = season_seqs

        X_train, y_train = X_train.to(DEVICE), y_train.to(DEVICE)
        weekday_train, season_train = weekday_train.to(DEVICE), season_train.to(DEVICE)

        if use_validation:
            X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)
            weekday_val, season_val = weekday_val.to(DEVICE), season_val.to(DEVICE)

        model = MultiEmbeddingLSTM(input_dim=len(features), output_dim=PREDICT, dropout=dropout).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        #loss 저장 리스트
        train_losses = []
        val_losses = []

        for epoch in range(EPOCHS):
            model.train()
            total_loss = 0
            idx = torch.randperm(len(X_train))

            for i in range(0, len(X_train), BATCH_SIZE):
                batch_idx = idx[i:i+BATCH_SIZE]
                X_batch = X_train[batch_idx]
                y_batch = y_train[batch_idx]
                weekday_batch = weekday_train[batch_idx]
                season_batch = season_train[batch_idx]

                output = model(X_batch, weekday_batch, season_batch)
                loss = criterion(output, y_batch)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            avg_loss = total_loss / (len(X_train) // BATCH_SIZE + 1)
            train_losses.append(avg_loss)

            if use_validation:
                model.eval()
                with torch.no_grad():
                    val_output = model(X_val, weekday_val, season_val)
                    val_loss = criterion(val_output, y_val).item()
                    val_losses.append(val_loss)

        visualize_loss(train_losses, val_losses if use_validation else None, key, save=True)

        trained_models[store_menu] = {
            'model': model.eval(),
            'scaler': scaler,
            'scaler_delta': scaler_delta,
            'last_sequence': {
                'X': train_vals[-LOOKBACK:],  # 수치 입력
                'weekday': store_train['weekday'].values[-LOOKBACK:],  # 임베딩용
                'season': store_train['season'].values[-LOOKBACK:]
            }
        }

    return trained_models

def visualize_loss(train_losses, val_losses, store_menu, save=False, out_dir="./loss_plots"):
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    if val_losses is not None:
        plt.plot(val_losses, label='Validation Loss')
    plt.title(f"[{store_menu}] Train vs Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    if save:
        os.makedirs(out_dir, exist_ok=True)
        safe_name = re.sub(r'[^\w\-_.]', '_', store_menu)
        path = os.path.join(out_dir, f"{safe_name}.png")
        plt.savefig(path)
    else:
        plt.show()

    plt.close()

#Prediction
def predict_lstm(test_df, trained_models, test_prefix: str, lower_bound_dict: dict):
    results = []

    for store_menu, store_test in test_df.groupby(['영업장명_메뉴명']):
        key = store_menu
        if key not in trained_models:
            continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']
        scaler_delta = trained_models[key]['scaler_delta']
        

        store_test_sorted = store_test.sort_values('영업일자').copy()
        store_test_sorted['영업일자'] = pd.to_datetime(store_test_sorted['영업일자'])
        store_test_sorted['weekday'] = store_test_sorted['영업일자'].dt.dayofweek.astype(int)
        store_test_sorted['month'] = store_test_sorted['영업일자'].dt.month
        store_test_sorted['season'] = store_test_sorted['month'].map({
            12:0,1:0,2:0,
            3:1,4:1,5:1,
            6:2,7:2,8:2,
            9:3,10:3,11:3
        }).astype(int)
        store_test_sorted['clipped_SQ'] = clip_iqr(store_test_sorted['매출수량'])

        #month 정규화
        store_test_sorted['month'] /= MONTH_SCALE

        # holiday feature 추가
        store_test_sorted = generate_combined_holiday_list(store_test_sorted, solar_md_holidays, lunar_solar_dates)

        # rolling_mean_7 계산
        store_test_sorted['rolling_mean_7'] = store_test_sorted['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #delta
        store_test_sorted['delta'] = store_test_sorted['clipped_SQ'].diff().fillna(0)
        store_test_sorted[['delta_scaled']] = scaler_delta.transform(store_test_sorted[['delta']])


        # feature_cols = ['매출수량','month','is_holiday','rolling_mean_7','delta_scaled']
        # recent_vals = store_test_sorted[feature_cols].values[-LOOKBACK:]

        # 최근 LOOKBACK 개 추출
        if len(store_test_sorted) < LOOKBACK:
            last_seq = trained_models[key]['last_sequence']
            x_input = torch.tensor([last_seq['X']]).float().to(DEVICE)
            weekday_seq = torch.tensor([last_seq['weekday']]).long().to(DEVICE)
            season_seq = torch.tensor([last_seq['season']]).long().to(DEVICE)
        else:
            recent_vals = store_test_sorted.iloc[-LOOKBACK:].copy()

            # clipped_SQ 생성 및 정규화
            recent_vals['clipped_SQ'] = clip_iqr(recent_vals['매출수량'])
            recent_vals['rolling_mean_7'] = recent_vals['clipped_SQ'].rolling(window=7, min_periods=1).mean()
            recent_vals['delta'] = recent_vals['clipped_SQ'].diff().fillna(0)
            recent_vals[['clipped_SQ', 'rolling_mean_7']] = scaler.transform(recent_vals[['clipped_SQ', 'rolling_mean_7']])
            recent_vals[['delta_scaled']] = scaler_delta.transform(recent_vals[['delta']])

            feature_cols = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
            x_input = torch.tensor([recent_vals[feature_cols].values]).float().to(DEVICE)
            weekday_seq = torch.tensor([recent_vals['weekday'].values]).long().to(DEVICE)
            season_seq = torch.tensor([recent_vals['season'].values]).long().to(DEVICE)


        # 예측
        with torch.no_grad():
            pred_scaled = model(x_input, weekday_seq, season_seq).squeeze().cpu().numpy()


        # 역정규화 및 하한 클리핑
        lower_bound = lower_bound_dict.get(key, 0)
        restored = []
        for i in range(PREDICT):
            val = pred_scaled[i]
            dummy_input = np.zeros((1, 2))
            dummy_input[0, 0] = val
            restored_val = scaler.inverse_transform(dummy_input)[0][0]
            #restored.append(max(restored_val, lower_bound))
            restored.append(max(restored_val, 1))  # 또는 lower_bound



        # 예측일자: TEST_00+1일 ~ TEST_00+7일
        # 결과 저장
        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]
        for d, val in zip(pred_dates, restored):
            results.append({
                '영업일자': d,
                '영업장명_메뉴명': store_menu[0],
                '매출수량': val
            })
    

    return pd.DataFrame(results)

def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    # (영업일자, 메뉴) → 매출수량 딕셔너리로 변환
    pred_dict = dict(zip(
        zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']),
        pred_df['매출수량']
    ))

    final_df = sample_submission.copy()

    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:  # 메뉴명들
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)

    return final_df
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:108: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: remove_leading_zeros_before_sales(g, min_zero_days))

# %%
# 학습
trained_models = train_lstm(train, use_validation=False, dropout=0.2)
# Out:
# Training LSTM: 100%|██████████| 193/193 [55:36<00:00, 17.29s/it]

# %%
all_preds = []

# 모든 test_*.csv 순회
test_files = sorted(glob.glob('./test/TEST_*.csv'))
df = pd.read_csv('./train/train.csv')
lower_bound_dict = compute_iqr_lower_bounds(df)
for path in test_files:
    test_df = pd.read_csv(path)
    # 파일명에서 접두어 추출 (예: TEST_00)
    filename = os.path.basename(path)
    test_prefix = re.search(r'(TEST_\d+)', filename).group(1)

    pred_df = predict_lstm(test_df, trained_models, test_prefix, lower_bound_dict)
    all_preds.append(pred_df)
    
full_pred_df = pd.concat(all_preds, ignore_index=True)

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
submission = convert_to_submission_format(full_pred_df, sample_submission)
submission.to_csv('./Prediction/v8_00_nonuse_valid.csv', index=False, encoding='utf-8-sig')
result = pd.read_csv('./Prediction/v8_00_nonuse_valid.csv')
display(result.head())
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.213624835014343' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.236123085021973' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.301072478294372' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1759738624095917' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7838101387023926' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7913883924484253' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0888589173555374' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.7704429626464844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.013239353895187' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.470185786485672' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.980204708874226' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.6883822828531265' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0029320120811462' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.772136554121971' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9708927869796753' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '29.948874473571777' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2010113894939423' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.60942831635475' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.472144678235054' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3430161774158478' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.394086837768555' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.7286165952682495' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8331270813941956' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0157658904790878' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.293468564748764' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.904320806264877' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.138603657484055' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.636912763118744' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9004014134407043' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.90156078338623' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.205236434936523' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.880112320184708' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.764318257570267' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.099702797830105' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0653414130210876' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0671989023685455' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.839453160762787' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4955231919884682' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.199947148561478' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.299372375011444' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3987230136990547' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8707694858312607' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.178518831729889' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6750851273536682' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.336895227432251' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.367039568722248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7940279096364975' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.9735267758369446' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.248279094696045' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.878870636224747' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.862671330571175' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.022605448961258' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.487790435552597' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.544663161039352' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.93220865726471' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.917950302362442' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.372324824333191' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.340741813182831' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '148.66339601576328' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.8645332250744104' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '41.219101786613464' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.4314490258693695' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.343790352344513' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0281971991062164' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7104309797286987' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6078954935073853' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7270387336611748' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.057182252407074' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.269504487514496' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.095007285475731' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1367197334766388' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.955568790435791' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.779237344861031' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.307087555527687' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0038431286811913' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.545414917171001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.209188759326935' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.312783778645098' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.850111812353134' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.079795762896538' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.71551376581192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.60374497435987' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0350603610277176' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.849072523415089' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.796702541410923' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.306001275777817' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.581818461418152' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3396250461228196' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.203902253881096' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.500053271651268' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.0912065068259835' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.280767192132771' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.262381413951516' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.53808580338955' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.65928200632334' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.450806401669979' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.7850898057222375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.935244232416153' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.866281040012836' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.601441830396652' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.74788935482502' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.4010628759861' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.611338794231415' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.02501319721341' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.583901852369308' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '52.95292809605599' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '41.25902563333511' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2521591745316982' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '34.68979699537158' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.087637018412352' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.979624973610044' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.716499418020248' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1046158298850064' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6347692348062992' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.427839024923742' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.475923307240009' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.749376644380391' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2109698355197906' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.074757069349289' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1423179507255554' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4250028133392334' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.088019609451294' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4650529623031616' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2971240282058716' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2101291120052338' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0832548886537552' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# ...
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.086268573999405' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.389371007680893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.449809968471527' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.120513200759888' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3043378293514252' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0907690227031708' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.143360286951065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1474788188934326' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2505270540714264' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.19326613843441' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0365170240402222' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.738703265786171' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.053679320961237' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2978326827287674' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0406479239463806' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1778442859649658' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4695239067077637' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3925023097544909' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0529454052448273' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.010611578822136' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5079450607299805' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.587571045383811' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0118410922586918' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1990483105182648' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0655423402786255' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0137718170881271' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0873442143201828' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.24379003047943' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.338675558567047' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40.33014118671417' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1853323876857758' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23.518469408154488' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2596866488456726' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2279535084962845' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_49723/1831058725.py:460: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1331875622272491' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
#          영업일자  느티나무 셀프BBQ_1인 수저세트  느티나무 셀프BBQ_BBQ55(단체)  \
# 0  TEST_00+1일            5.213625              1.000000
# 1  TEST_00+2일            1.000000              7.716499
# 2  TEST_00+3일            1.000000             10.913766
# 3  TEST_00+4일            2.442814             22.566948
# 4  TEST_00+5일            5.997596             33.357596
#
#    느티나무 셀프BBQ_대여료 30,000원  느티나무 셀프BBQ_대여료 60,000원  느티나무 셀프BBQ_대여료 90,000원  \
# 0                8.236123                3.301072                     1.0
# 1                1.182456                1.000000                     1.0
# 2                2.747096                1.000000                     1.0
# 3                2.313780                1.143677                     1.0
# 4                2.150168                1.000000                     1.0
#
#    느티나무 셀프BBQ_본삼겹 (단품,실내)  느티나무 셀프BBQ_스프라이트 (단체)  느티나무 셀프BBQ_신라면  \
# 0                1.175974               1.000000        3.783810
# 1                1.000000               3.104616        1.262316
# 2                1.000000               2.915212        1.245697
# 3                1.000000               4.199558        1.745593
# 4                1.000000               8.234822        3.638564
#
#    느티나무 셀프BBQ_쌈야채세트  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  화담숲주막_찹쌀식혜   화담숲주막_콜라  \
# 0          1.791388  ...     9.401063      17.611339   21.025013  10.583902
# 1          1.000000  ...     3.302187       5.579482    5.132525   1.529116
# 2          1.000000  ...     4.012148       5.462798    7.120508   2.022823
# 3          1.000000  ...     3.005275       5.550216    5.928305   1.264870
# 4          1.000000  ...     2.421804       3.157095    9.286099   1.598526
#
#    화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  \
# 0   52.952928     41.259026         2.252159        34.689797        7.087637
# 1    8.796068      8.617811         1.156257        13.972455        4.453104
# 2   29.740788     21.959167         1.160838        20.748660        3.802060
# 3   15.828438     19.316276         1.000000        10.723323        4.123519
# 4   20.656115     19.324054         1.484255        13.813648        4.145227
#
#    화담숲카페_현미뻥스크림
# 0     11.979625
# 1      2.552685
# 2      1.000000
# 3      1.000000
# 4      3.540968
#
# [5 rows x 194 columns]
