# %%
# 1. 빠른 테스트 (5분)
from complete_advanced_model import quick_test_fixed_model
success = quick_test_fixed_model()

if success:
    print("✅ 테스트 통과!")
    
    # 2. 전체 파이프라인 실행
    from complete_advanced_model import run_fixed_advanced_pipeline
    submission, predictions, model = run_fixed_advanced_pipeline()
else:
    print("❌ 추가 문제 확인 필요")
# Out:
# INFO:complete_advanced_model:기본 특성 생성 시작...
# INFO:complete_advanced_model:업장별 프로파일 계산 중...
# INFO:complete_advanced_model:특성 생성 완료. 총 특성 수: 34
# INFO:complete_advanced_model:시퀀스 생성 중 (mode: train)...
# 🔧 수정된 함수들:
#   • create_safe_sequences() - 특성 컬럼 선택 로직 개선
#   • quick_test_fixed_model_v2() - 더 큰 샘플로 테스트
#
# 실행: quick_test_fixed_model_v2()
# ⚡ 수정된 모델 빠른 테스트 v2
# ...
# 전체 데이터: (102676, 3)
# 샘플 데이터: (9650, 3)
# 업장메뉴 수: 193
# 충분한 데이터 (≥35일)를 가진 업장메뉴: 193개
# ✅ 특성 생성 테스트...
# 특성 수: 35
# ✅ 시퀀스 생성 테스트...
# 📊 느티나무 셀프BBQ_1인 수저세트: 사용 가능한 특성 20개
#     특성 목록: ['month', 'day', 'dayofweek', 'dayofyear', 'week', 'month_sin', 'month_cos', 'dow_sin', 'dow_cos', 'day_sin']...
# ✅ 전역 특성 컬럼 설정: 20개
# ✅ 느티나무 셀프BBQ_1인 수저세트: 20개 특성 사용
# 📊 느티나무 셀프BBQ_BBQ55(단체): 사용 가능한 특성 20개
#     특성 목록: ['month', 'day', 'dayofweek', 'dayofyear', 'week', 'month_sin', 'month_cos', 'dow_sin', 'dow_cos', 'day_sin']...
# ✅ 느티나무 셀프BBQ_BBQ55(단체): 20개 특성 사용
# 📊 느티나무 셀프BBQ_대여료 30,000원: 사용 가능한 특성 20개
# ...
