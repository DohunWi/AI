# %%
# =========================
#version00
# =========================

import os
import random
import glob
import re

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler

import torch
import torch.nn as nn
from tqdm import tqdm

import matplotlib.pyplot as plt
from korean_lunar_calendar import KoreanLunarCalendar


plt.rcParams['font.family'] = 'AppleGothic'  # macOS


#Fixed Random Seed  & Setting Hyperparameter
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)


set_seed(42)

LOOKBACK, PREDICT, BATCH_SIZE, EPOCHS = 28, 7, 32, 50
DEVICE = torch.device("cpu")
MONTH_SCALE = 12

MIN_SEQUENCE_COUNT = 10

def get_lunar_to_solar(years, lunar_month, lunar_day, span=1):
    calendar = KoreanLunarCalendar()
    dates = []
    for year in years:
        for offset in range(-span, span+1):
            try:
                calendar.setLunar(year, lunar_month, lunar_day + offset, False)
                dates.append(calendar.SolarIsoFormat())
            except:
                pass  # 예외 처리: 음력 마지막날 초과
    return dates
# 예시: 2023 ~ 2025
years = [2023, 2024, 2025]
lunar_solar_dates = []
lunar_solar_dates += get_lunar_to_solar(years, 1, 1, span=1)   # 설날 ±1
lunar_solar_dates += get_lunar_to_solar(years, 8, 15, span=1)  # 추석 ±1

solar_md_holidays = [
    (1, 1),   # 신정
    (3, 1),   # 삼일절
    (5, 5),   # 어린이날
    (6, 6),   # 현충일
    (8, 15),  # 광복절
    (10, 3),  # 개천절
    (10, 9),  # 한글날
    (12, 25), # 크리스마스
]

def generate_combined_holiday_list(df, solar_md_list, lunar_solar_list):
    df = df.copy()
    df['영업일자'] = pd.to_datetime(df['영업일자'])

    # 양력 기반 holiday 판별
    df['is_solar_holiday'] = df['영업일자'].apply(
        lambda x: (x.month, x.day) in solar_md_list
    )

    # 음력 변환된 holiday 포함
    lunar_set = set(pd.to_datetime(lunar_solar_list))
    df['is_lunar_holiday'] = df['영업일자'].isin(lunar_set)

    # 최종 통합
    df['is_holiday'] = (df['is_solar_holiday'] | df['is_lunar_holiday']).astype(int)
    df = df.drop(columns=['is_solar_holiday', 'is_lunar_holiday'])
    return df

def remove_leading_zeros_before_sales(df, min_zero_days=90):
    """
    매출 시작 전 연속된 0이 일정 기간 이상이면, 그 전 구간은 제거
    """
    sales_started = df['매출수량'] > 0
    if not sales_started.any():
        return df  # 매출이 전혀 없는 경우 그대로 반환

    first_sale_idx = sales_started.idxmax()

    # 매출 시작 전 구간이 충분히 긴 0으로 구성되어 있다면 제거
    df_before = df.loc[:first_sale_idx - 1]
    if len(df_before) >= min_zero_days and (df_before['매출수량'] == 0).all():
        return df.loc[first_sale_idx:]  # 매출 시작부터 반환
    else:
        return df  # 그대로 반환

def filter_all_menus_by_leading_zeros(train_df: pd.DataFrame, min_zero_days: int = 90) -> pd.DataFrame:
    """
    모든 메뉴에 대해 remove_leading_zeros_before_sales 적용.
    groupby.apply(include_groups=...) 대신 그룹 순회로 FutureWarning 제거.
    """
    parts = []
    # sort=False를 유지해 기존 순서 보존(원하면 True로 변경 가능)
    for _, g in train_df.groupby('영업장명_메뉴명', sort=False):
        parts.append(remove_leading_zeros_before_sales(g, min_zero_days))
    if parts:
        return pd.concat(parts, ignore_index=True)
    # 비어 있으면 원본 형태 유지
    return train_df.reset_index(drop=True)

#Data load
train = pd.read_csv('./train/train.csv')
train = generate_combined_holiday_list(train, solar_md_holidays, lunar_solar_dates)
train = filter_all_menus_by_leading_zeros(train, min_zero_days=90)


#Define Model
class MultiEmbeddingLSTM(nn.Module):
    def __init__(
        self,
        input_dim,                  # 수치 feature 수
        hidden_dim=64,
        num_layers=2,
        output_dim=7,
        num_weekdays=7,
        weekday_embed_dim=3,
        num_seasons=4,
        season_embed_dim=2,
        dropout=0.3
    ):
        super().__init__()

        # 임베딩
        self.weekday_embedding = nn.Embedding(num_weekdays, weekday_embed_dim)
        self.season_embedding = nn.Embedding(num_seasons, season_embed_dim)

        # LayerNorm for embedding
        self.weekday_norm = nn.LayerNorm(weekday_embed_dim)
        self.season_norm = nn.LayerNorm(season_embed_dim)

        # Dropout after embedding
        self.embedding_dropout = nn.Dropout(dropout)

        total_input_dim = input_dim + weekday_embed_dim + season_embed_dim

        # LSTM
        self.lstm = nn.LSTM(total_input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)

        # LSTM output dropout
        self.post_lstm_dropout = nn.Dropout(dropout)

        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, weekday_ids, season_ids):
        """
        x: (B, T, input_dim)
        weekday_ids: (B, T)
        season_ids: (B, T)
        """
        weekday_embed = self.weekday_embedding(weekday_ids)      # (B, T, D2)
        season_embed = self.season_embedding(season_ids)         # (B, T, D3)

        # 정규화
        weekday_embed = self.weekday_norm(weekday_embed)
        season_embed = self.season_norm(season_embed)

        x_concat = torch.cat([x, weekday_embed, season_embed], dim=-1)  # (B, T, total_dim)
        x_concat = self.embedding_dropout(x_concat)

        out, _ = self.lstm(x_concat)
        out = self.post_lstm_dropout(out)

        return self.fc(out[:, -1, :])
    
def clip_iqr(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    upper = q3 + 1.5 * iqr
    return np.clip(series, None, upper)

def compute_iqr_lower_bounds(train_df):
    lower_bounds = {}
    for menu, group in train_df.groupby('영업장명_메뉴명'):
        q1 = group['매출수량'].quantile(0.25)
        q3 = group['매출수량'].quantile(0.75)
        iqr = q3 - q1
        lower = max(q1 - 1.5 * iqr, 0)
        menu_key = menu[0] if isinstance(menu, tuple) else menu
        lower_bounds[menu_key] = lower
    return lower_bounds

#Train
def train_lstm(train_df, use_validation=True, dropout=0.3):
    trained_models = {}

    for store_menu, group in tqdm(train_df.groupby(['영업장명_메뉴명']), desc ='Training LSTM'):
        #시계열 정렬 , preprocessing
        key = store_menu[0] if isinstance(store_menu, tuple) else store_menu
        store_train = group.sort_values('영업일자').copy()
        store_train['영업일자'] = pd.to_datetime(store_train['영업일자'])
        store_train['weekday'] = store_train['영업일자'].dt.dayofweek
        store_train['weekday'] = store_train['weekday'].astype(int)
        store_train['month'] = store_train['영업일자'].dt.month

        store_train['season'] = store_train['month'].map({
            12:0,1:0,2:0, #winter
            3:1,4:1,5:1, #spring
            6:2,7:2,8:2, #summer
            9:3,10:3,11:3 #fall
        })  
        store_train['season'] = store_train['season'].astype(int)

        store_train['month'] /= MONTH_SCALE
        


        #data clipping
        store_train['clipped_SQ'] = clip_iqr(store_train['매출수량'])
        store_train['delta'] = store_train['clipped_SQ'].diff().fillna(0)
        
        #rolling_mean_7
        store_train['rolling_mean_7'] = store_train['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #train/validation split을 안전하게 하기 위해 여유분 데이터를 확보하는 목적 -> MIN_SEQUENCE_COUNT
        if len(store_train) < LOOKBACK + PREDICT + MIN_SEQUENCE_COUNT:
            continue

        #features = ['clipped_SQ','weekday','month','season', 'is_holiday', 'rolling_mean_7','delta_scaled', 'store_id']
        features = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
        scaler = MinMaxScaler()

        ##정규화, 요일정보 
        store_train[['clipped_SQ','rolling_mean_7']] = scaler.fit_transform(store_train[['clipped_SQ', 'rolling_mean_7']])
        scaler_delta = MinMaxScaler()
        store_train[['delta_scaled']] = scaler_delta.fit_transform(store_train[['delta']])


        train_vals = store_train[features].values  # shape: (N, 8)

        # 시퀀스 생성
        X, y, weekday_seqs, season_seqs = [], [], [], []

        for i in range(len(store_train) - LOOKBACK - PREDICT + 1):
            X.append(store_train[features].values[i:i+LOOKBACK])
            y.append(store_train['clipped_SQ'].values[i+LOOKBACK:i+LOOKBACK+PREDICT])
            weekday_seqs.append(store_train['weekday'].values[i:i+LOOKBACK])
            season_seqs.append(store_train['season'].values[i:i+LOOKBACK])

        X = torch.tensor(X).float()
        y = torch.tensor(y).float()

        weekday_seqs = torch.tensor(weekday_seqs).long()
        season_seqs = torch.tensor(season_seqs).long()

        if use_validation:
            # Train/Validation split (기존 방식 유지)
            split_idx = int(len(X) * 0.8)
            X_train, X_val = X[:split_idx], X[split_idx:]
            y_train, y_val = y[:split_idx], y[split_idx:]
            weekday_train, weekday_val = weekday_seqs[:split_idx], weekday_seqs[split_idx:]
            season_train, season_val = season_seqs[:split_idx], season_seqs[split_idx:]
        else:
            # 전체 데이터 학습에 사용
            X_train = X
            y_train = y
            weekday_train = weekday_seqs
            season_train = season_seqs

        X_train, y_train = X_train.to(DEVICE), y_train.to(DEVICE)
        weekday_train, season_train = weekday_train.to(DEVICE), season_train.to(DEVICE)

        if use_validation:
            X_val, y_val = X_val.to(DEVICE), y_val.to(DEVICE)
            weekday_val, season_val = weekday_val.to(DEVICE), season_val.to(DEVICE)

        model = MultiEmbeddingLSTM(input_dim=len(features), output_dim=PREDICT, dropout=dropout).to(DEVICE)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.MSELoss()

        #loss 저장 리스트
        train_losses = []
        val_losses = []

        for epoch in range(EPOCHS):
            model.train()
            total_loss = 0
            idx = torch.randperm(len(X_train))

            for i in range(0, len(X_train), BATCH_SIZE):
                batch_idx = idx[i:i+BATCH_SIZE]
                X_batch = X_train[batch_idx]
                y_batch = y_train[batch_idx]
                weekday_batch = weekday_train[batch_idx]
                season_batch = season_train[batch_idx]

                output = model(X_batch, weekday_batch, season_batch)
                loss = criterion(output, y_batch)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            avg_loss = total_loss / (len(X_train) // BATCH_SIZE + 1)
            train_losses.append(avg_loss)

            if use_validation:
                model.eval()
                with torch.no_grad():
                    val_output = model(X_val, weekday_val, season_val)
                    val_loss = criterion(val_output, y_val).item()
                    val_losses.append(val_loss)

        visualize_loss(train_losses, val_losses if use_validation else None, key, save=True)

        trained_models[store_menu] = {
            'model': model.eval(),
            'scaler': scaler,
            'scaler_delta': scaler_delta,
            'last_sequence': {
                'X': train_vals[-LOOKBACK:],  # 수치 입력
                'weekday': store_train['weekday'].values[-LOOKBACK:],  # 임베딩용
                'season': store_train['season'].values[-LOOKBACK:]
            }
        }

    return trained_models

def visualize_loss(train_losses, val_losses, store_menu, save=False, out_dir="./loss_plots"):
    plt.figure()
    plt.plot(train_losses, label='Train Loss')
    if val_losses is not None:
        plt.plot(val_losses, label='Validation Loss')
    plt.title(f"[{store_menu}] Train vs Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    if save:
        os.makedirs(out_dir, exist_ok=True)
        safe_name = re.sub(r'[^\w\-_.]', '_', store_menu)
        path = os.path.join(out_dir, f"{safe_name}.png")
        plt.savefig(path)
    else:
        plt.show()

    plt.close()

#Prediction
def predict_lstm(test_df, trained_models, test_prefix: str, lower_bound_dict: dict):
    results = []

    for store_menu, store_test in test_df.groupby(['영업장명_메뉴명']):
        key = store_menu
        if key not in trained_models:
            continue

        model = trained_models[key]['model']
        scaler = trained_models[key]['scaler']
        scaler_delta = trained_models[key]['scaler_delta']
        

        store_test_sorted = store_test.sort_values('영업일자').copy()
        store_test_sorted['영업일자'] = pd.to_datetime(store_test_sorted['영업일자'])
        store_test_sorted['weekday'] = store_test_sorted['영업일자'].dt.dayofweek.astype(int)
        store_test_sorted['month'] = store_test_sorted['영업일자'].dt.month
        store_test_sorted['season'] = store_test_sorted['month'].map({
            12:0,1:0,2:0,
            3:1,4:1,5:1,
            6:2,7:2,8:2,
            9:3,10:3,11:3
        }).astype(int)
        store_test_sorted['clipped_SQ'] = clip_iqr(store_test_sorted['매출수량'])

        #month 정규화
        store_test_sorted['month'] /= MONTH_SCALE

        # holiday feature 추가
        store_test_sorted = generate_combined_holiday_list(store_test_sorted, solar_md_holidays, lunar_solar_dates)

        # rolling_mean_7 계산
        store_test_sorted['rolling_mean_7'] = store_test_sorted['clipped_SQ'].rolling(window=7, min_periods=1).mean()

        #delta
        store_test_sorted['delta'] = store_test_sorted['clipped_SQ'].diff().fillna(0)
        store_test_sorted[['delta_scaled']] = scaler_delta.transform(store_test_sorted[['delta']])


        # feature_cols = ['매출수량','month','is_holiday','rolling_mean_7','delta_scaled']
        # recent_vals = store_test_sorted[feature_cols].values[-LOOKBACK:]

        # 최근 LOOKBACK 개 추출
        if len(store_test_sorted) < LOOKBACK:
            last_seq = trained_models[key]['last_sequence']
            x_input = torch.tensor([last_seq['X']]).float().to(DEVICE)
            weekday_seq = torch.tensor([last_seq['weekday']]).long().to(DEVICE)
            season_seq = torch.tensor([last_seq['season']]).long().to(DEVICE)
        else:
            recent_vals = store_test_sorted.iloc[-LOOKBACK:].copy()

            # clipped_SQ 생성 및 정규화
            recent_vals['clipped_SQ'] = clip_iqr(recent_vals['매출수량'])
            recent_vals['rolling_mean_7'] = recent_vals['clipped_SQ'].rolling(window=7, min_periods=1).mean()
            recent_vals['delta'] = recent_vals['clipped_SQ'].diff().fillna(0)
            recent_vals[['clipped_SQ', 'rolling_mean_7']] = scaler.transform(recent_vals[['clipped_SQ', 'rolling_mean_7']])
            recent_vals[['delta_scaled']] = scaler_delta.transform(recent_vals[['delta']])

            feature_cols = ['clipped_SQ', 'rolling_mean_7', 'delta_scaled', 'month', 'is_holiday']
            x_input = torch.tensor([recent_vals[feature_cols].values]).float().to(DEVICE)
            weekday_seq = torch.tensor([recent_vals['weekday'].values]).long().to(DEVICE)
            season_seq = torch.tensor([recent_vals['season'].values]).long().to(DEVICE)


        # 예측
        with torch.no_grad():
            pred_scaled = model(x_input, weekday_seq, season_seq).squeeze().cpu().numpy()


        # 역정규화 및 하한 클리핑
        lower_bound = lower_bound_dict.get(key, 0)
        restored = []
        for i in range(PREDICT):
            val = pred_scaled[i]
            dummy_input = np.zeros((1, 2))
            dummy_input[0, 0] = val
            restored_val = scaler.inverse_transform(dummy_input)[0][0]
            #restored.append(max(restored_val, lower_bound))
            restored.append(max(restored_val, 1))  # 또는 lower_bound



        # 예측일자: TEST_00+1일 ~ TEST_00+7일
        # 결과 저장
        pred_dates = [f"{test_prefix}+{i+1}일" for i in range(PREDICT)]
        for d, val in zip(pred_dates, restored):
            results.append({
                '영업일자': d,
                '영업장명_메뉴명': store_menu[0],
                '매출수량': val
            })
    

    return pd.DataFrame(results)

def convert_to_submission_format(pred_df: pd.DataFrame, sample_submission: pd.DataFrame):
    # (영업일자, 메뉴) → 매출수량 딕셔너리로 변환
    pred_dict = dict(zip(
        zip(pred_df['영업일자'], pred_df['영업장명_메뉴명']),
        pred_df['매출수량']
    ))

    final_df = sample_submission.copy()

    for row_idx in final_df.index:
        date = final_df.loc[row_idx, '영업일자']
        for col in final_df.columns[1:]:  # 메뉴명들
            final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)

    return final_df

# %%
train = pd.read_csv('./train/train.csv')
train = generate_combined_holiday_list(train, solar_md_holidays, lunar_solar_dates)
train = filter_all_menus_by_leading_zeros(train, min_zero_days=90)
trained_models = train_lstm(train, use_validation=False, dropout=0.1)
# Out:
# Training LSTM: 100%|██████████| 193/193 [31:02<00:00,  9.65s/it]

# %%
all_preds = []

# 모든 test_*.csv 순회
test_files = sorted(glob.glob('./test/TEST_*.csv'))
df = pd.read_csv('./train/train.csv')
lower_bound_dict = compute_iqr_lower_bounds(df)
for path in test_files:
    test_df = pd.read_csv(path)
    # 파일명에서 접두어 추출 (예: TEST_00)
    filename = os.path.basename(path)
    test_prefix = re.search(r'(TEST_\d+)', filename).group(1)

    pred_df = predict_lstm(test_df, trained_models, test_prefix, lower_bound_dict)
    all_preds.append(pred_df)
    
full_pred_df = pd.concat(all_preds, ignore_index=True)

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
submission = convert_to_submission_format(full_pred_df, sample_submission)
submission.to_csv('./Prediction/model_v0_2.csv', index=False, encoding='utf-8-sig')
result = pd.read_csv('./Prediction/model_v0_2.csv')
display(result.head())
# Out:
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.246564745903015' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.334482192993164' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.246776700019836' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.165691021829844' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0672235786914825' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7874649167060852' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2088166177272797' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.443871945142746' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.439263686537743' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.625753939151764' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.380440464243293' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.881150960922241' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.625309802591801' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.533181384205818' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0964020267128944' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.811259478330612' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5039857625961304' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '34.823004841804504' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1464588530361652' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6881459951400757' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.70647631585598' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.829965081065893' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.791123867034912' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3958000540733337' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.1748828887939453' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.79865625500679' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.947295024991035' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.494005560874939' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.015233039855957' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0073988139629364' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.088673621416092' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.245859146118164' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.488209754228592' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.241568714380264' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.9167046546936035' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.269309526309371' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.75784695148468' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5726744532585144' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.454703986644745' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3720833510160446' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.045742243528366' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6069434881210327' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.669616624712944' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7843328416347504' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.772231549024582' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4671455323696136' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0780662298202515' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0115411132574081' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1871911585330963' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.5154417753219604' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3817653059959412' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.0480581521987915' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.081539168953896' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.86068249354139' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5387974679470062' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3235638439655304' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.00304651260376' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0008177906274796' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.564601957798004' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.719566762447357' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3471564650535583' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.7417683005332947' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '133.77473037689924' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2227421924471855' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.537876188755035' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.220203846693039' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.2343392968177795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5257127583026886' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5223057568073273' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0241218656301498' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.722165048122406' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.1116289496421814' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.345551550388336' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0580790787935257' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.6911432892084122' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.608318507671356' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.248988463543355' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.1462178602814665' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.833098946139216' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.906095400452614' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21.853172231465578' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.576749417930841' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.381967291235923' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.700992405414581' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.160612596198916' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3334256410598755' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.462683632969856' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.406404733657837' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.1137982457876205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.911333441734314' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.850321976467968' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.787598064169287' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5553133487701416' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.041797515004873' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.9092403082177043' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.123762138187885' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.57153121381998' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.49234382249415' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.7650576122105122' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.6495234481990337' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.151722356677056' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.426414519548416' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13.540856167674065' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.55161988735199' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.391849502921104' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.205499067902565' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.541497841477394' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.839383952319622' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2639696449041367' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '47.10127813741565' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '40.461737886071205' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.4272510781884193' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '31.865118583664298' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.409114468842745' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.192557573318481' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.2971705310046673' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.947522135917097' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.8553335703909397' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3124874234199524' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '27.44881615042687' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.8551458138972519' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2110207974910736' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.724553443491459' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5894649922847748' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.34283447265625' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5358228981494904' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# ...
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3305799663066864' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1645836383104324' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.396680474281311' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3521003723144531' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4543139934539795' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.2156523168087006' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1298589408397675' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.5117307007312775' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.726294755935669' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1498458683490753' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1987143009901047' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.074020192027092' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.008407175540924' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0573622584342957' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.3093061055988073' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.033316969871521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.3665865361690521' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1633404158055782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1943982541561127' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.320021688938141' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.2038408517837524' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.214812621474266' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1680257320404053' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0904038697481155' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.1874756962060928' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.202586144208908' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '36.316736564040184' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.516079902648926' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.429545968770981' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '41.26627326011658' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.140005975961685' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.965908527374268' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.620867013931274' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.4877109229564667' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.403186246752739' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
# /var/folders/r4/sdnz117n6pl22zr9jhhv5vbm0000gn/T/ipykernel_70596/84578561.py:493: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1.0211262106895447' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   final_df.loc[row_idx, col] = pred_dict.get((date, col), 0)
#          영업일자  느티나무 셀프BBQ_1인 수저세트  느티나무 셀프BBQ_BBQ55(단체)  \
# 0  TEST_00+1일            5.246565              1.000000
# 1  TEST_00+2일            3.138014              1.000000
# 2  TEST_00+3일            4.105437              1.000000
# 3  TEST_00+4일            4.274550              2.342834
# 4  TEST_00+5일            5.373190              8.130111
#
#    느티나무 셀프BBQ_대여료 30,000원  느티나무 셀프BBQ_대여료 60,000원  느티나무 셀프BBQ_대여료 90,000원  \
# 0                8.334482                3.246777                     1.0
# 1                1.310029                1.000000                     1.0
# 2                2.915119                1.000000                     1.0
# 3                3.081724                1.497812                     1.0
# 4                2.983918                1.705261                     1.0
#
#    느티나무 셀프BBQ_본삼겹 (단품,실내)  느티나무 셀프BBQ_스프라이트 (단체)  느티나무 셀프BBQ_신라면  \
# 0                     1.0               1.165691        3.067224
# 1                     1.0               3.708811        1.193534
# 2                     1.0               3.386128        1.162731
# 3                     1.0               6.385937        1.640270
# 4                     1.0              10.671600        3.746515
#
#    느티나무 셀프BBQ_쌈야채세트  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  화담숲주막_찹쌀식혜  화담숲주막_콜라  \
# 0          1.787465  ...     4.205499      20.541498   16.839384  3.263970
# 1          1.000000  ...     2.007156       7.330198    5.478775  1.541103
# 2          1.000000  ...     1.973853       5.594329    6.733729  1.318015
# 3          1.000000  ...     1.470758       6.302963    6.566702  1.000000
# 4          1.000000  ...     2.493456       7.295999    6.639060  1.543267
#
#    화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  \
# 0   47.101278     40.461738         2.427251        31.865119        6.409114
# 1   10.461349      9.466569         1.000000        14.699027        2.874084
# 2   22.891823     28.408273         2.603410        30.524644        3.642829
# 3   20.621630     16.432891         3.567352        22.850862        3.246390
# 4   25.938401     22.192622         2.164263        17.427229        3.045818
#
#    화담숲카페_현미뻥스크림
# 0     15.192558
# 1      2.438804
# 2      2.756491
# 3      3.766711
# 4      3.698831
#
# [5 rows x 194 columns]
